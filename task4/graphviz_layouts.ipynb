# %%
import networkx as nx
import collections
import matplotlib.pyplot as plt

# %%
try:
    import pygraphviz
    from networkx.drawing.nx_agraph import graphviz_layout
except ImportError:
    try:
        import pydot
        from networkx.drawing.nx_pydot import graphviz_layout
    except ImportError:
        raise ImportError("This example needs Graphviz and either "
                          "PyGraphviz or pydot")

# %%
path = 'data/graph/graph.edgelist'
G = nx.read_edgelist(path)
# nx.write_gexf(G, "graph.gexf")
nx.info(G)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 5494\nNumber of edges: 37707\nAverage degree:  13.7266'

# %%
pos = graphviz_layout(G, prog='sfdp')
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=20, alpha=0.2, node_color="blue", with_labels=False)
plt.axis('equal')
plt.show()

# %%
pos = graphviz_layout(G, prog='twopi')
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=20, alpha=0.5, node_color="blue", with_labels=False)
plt.axis('equal')
plt.show()

# %%
pos = graphviz_layout(G, prog='twopi')
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=20, alpha=0.1, node_color="blue", with_labels=False)
plt.axis('equal')
plt.show()

# %%
pos = graphviz_layout(G, prog='neato')
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=20, alpha=0.5, node_color="blue", with_labels=False)
plt.axis('equal')
plt.show()

# %%
pos = graphviz_layout(G, prog='neato')
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=20, alpha=0.1, node_color="blue", with_labels=False)
plt.axis('equal')
plt.show()

# %%
# pos = graphviz_layout(G, prog='dot')
# plt.figure(figsize=(8, 8))
# nx.draw(G, pos, node_size=20, alpha=0.1, node_color="blue", with_labels=False)
# plt.axis('equal')
# plt.show()
## ERROR: AssertionError: 3221225725

# %%
pos = graphviz_layout(G, prog='circo')
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=20, alpha=0.1, node_color="blue", with_labels=False)
plt.axis('equal')
plt.show()
## Too long to calc

# %%
nx.draw(G, node_size=15, alpha=0.5)

# %%
nx.draw_kamada_kawai(G, node_size=15, alpha=0.5)

# %%
nx.draw_circular(G, node_size=15, alpha=0.5)

# %%
nx.draw_spectral(G, node_size=15, alpha=0.5)

# %%
nx.draw_spring(G, node_size=15, alpha=0.5)

# %%
nx.draw_shell(G, node_size=15, alpha=0.5)
